# %%
# !pip install folium

# %%
import folium
mymap = folium.Map(location = [12.972442, 77.580643],
                   width = 950,
                   height = 550,
                   zoom_start = 12,
                   tiles = 'openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
marker1 = folium.Marker([12.972442, 77.580643], popup='My City')
marker2 = folium.Marker([13.042091, 77.590874], popup='My Shop')
marker3 = folium.Marker([13.156479, 77.557386], popup='My Home')
marker4 = folium.Marker([13.156195, 77.561764], popup='My school')
marker5 = folium.Marker([12.995425, 77.584910], popup='My place')
marker1.add_to(mymap)
marker2.add_to(mymap)
marker3.add_to(mymap)
marker4.add_to(mymap)
marker5.add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
banglore_coords = (12.972442, 77.580643)
map_banglore = folium.Map(location=banglore_coords, zoom_start=12)
places = {
    "My City":(12.972442, 77.580643),
    "My Shop":(13.042091, 77.590874),
    "My Home":(13.156479, 77.557386),
    "My school":(13.156195, 77.561764),
    "My Place":(12.995425, 77.584910)
}

# %%
images={
    "My City":"data:image/jpeg;base64,..."
    "My Shop":"data:image/jpeg;base64,..."
    "My Home":"data:image/jpeg;base64,...
    ..."
for place, coords in place.items():
  popup_content=f'<b>{place}</b>'
  folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bang)
  map_bang
